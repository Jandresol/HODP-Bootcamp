# %% [markdown]
# Analyzing the relative attendance rate for each college

# %%
import pandas as pd
import numpy as np

college = pd.read_csv('college.csv')

import plotly.graph_objects as go

# HODP colors
monochrome_colors = ['#251616', '#760000', '#C63F3F', '#E28073', '#F1D3CF']
primary_colors = ['#C63F3F', '#F4B436', '#83BFCC', '#455574', '#E2DDDB']

# HODP template
theme_hodp = go.layout.Template(
    layout=go.Layout(
        title = {'font':{'size':24, 'family':"Helvetica", 'color':monochrome_colors[0]}, 'pad':{'t':100, 'r':0, 'b':0, 'l':0}},
        font = {'size':18, 'family':'Helvetica', 'color':'#717171'},
        xaxis = {'ticks': "outside",
                'tickfont': {'size': 14, 'family':"Helvetica"},
                'showticksuffix': 'all',
                'showtickprefix': 'last',
                'showline': True,
                'title':{'font':{'size':18, 'family':'Helvetica'}, 'standoff':20},
                'automargin': True
                },
        yaxis = {'ticks': "outside",
                'tickfont': {'size': 14, 'family':"Helvetica"},
                'showticksuffix': 'all',
                'showtickprefix': 'last',
                'title':{'font':{'size':18, 'family':'Helvetica'}, 'standoff':20},
                'showline': True,
                'automargin': True
                },
        legend = {'bgcolor':'rgba(0,0,0,0)', 
                'title':{'font':{'size':18, 'family':"Helvetica", 'color':monochrome_colors[0]}}, 
                'font':{'size':14, 'family':"Helvetica"}, 
                'yanchor':'bottom'
                },
        colorscale = {'diverging':monochrome_colors},
        coloraxis = {'autocolorscale':True, 
                'cauto':True, 
                'colorbar':{'tickfont':{'size':14,'family':'Helvetica'}, 'title':{'font':{'size':18, 'family':'Helvetica'}}},
                }
    )
)

# %%
import plotly.graph_objects as go

x = college['par_income_lab'][0:13]
y1 = college['rel_attend'][0:13]
y2 = college['rel_attend'][14:27]
y3 = college['rel_attend'][28:41]
y4 = college['rel_attend'][42:55]
y5 = college['rel_attend'][56:69]
y6 = college['rel_attend'][70:83]
y7 = college['rel_attend'][84:97]
y8 = college['rel_attend'][98:111]
y9 = college['rel_attend'][112:125]
y10 = college['rel_attend'][126:139]
y11 = college['rel_attend'][140:153]
y12 = college['rel_attend'][154:167]


fig = go.Figure()

fig.add_trace(go.Scatter(
    x=x,
    y=y1,
    name='Brown',
    marker_color=primary_colors[0]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y2,
    name='Columbia',
    marker_color=primary_colors[1]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y3,
    name='Cornell',
    marker_color=primary_colors[2]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y4,
    name='Dartmouth',
    marker_color=primary_colors[3]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y5,
    name='Duke',
    marker_color=primary_colors[4]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y6,
    name='Harvard',
    marker_color=primary_colors[0]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y7,
    name='MIT',
    marker_color=primary_colors[1]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y8,
    name='Princeton',
    marker_color=primary_colors[2]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y9,
    name='Stanford',
    marker_color=primary_colors[3]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y10,
    name='UChicago',
    marker_color=primary_colors[4]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y11,
    name='UPenn',
    marker_color=primary_colors[0]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y12,
    name='Yale',
    marker_color=primary_colors[1]
))
fig.update_layout(title_text="Relative Attendance Rates with Same Test scores")

fig.update_layout(yaxis_type="linear")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

x = college['par_income_lab'][0:13]
y1 = college['rel_attend_unwgt'][0:13]
y2 = college['rel_attend_unwgt'][14:27]
y3 = college['rel_attend_unwgt'][28:41]
y4 = college['rel_attend_unwgt'][42:55]
y5 = college['rel_attend_unwgt'][56:69]
y6 = college['rel_attend_unwgt'][70:83]
y7 = college['rel_attend_unwgt'][84:97]
y8 = college['rel_attend_unwgt'][98:111]
y9 = college['rel_attend_unwgt'][112:125]
y10 = college['rel_attend_unwgt'][126:139]
y11 = college['rel_attend_unwgt'][140:153]
y12 = college['rel_attend_unwgt'][154:167]


fig = go.Figure()

fig.add_trace(go.Scatter(
    x=x,
    y=y1,
    name='Brown',
    marker_color=primary_colors[0]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y2,
    name='Columbia',
    marker_color=primary_colors[1]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y3,
    name='Cornell',
    marker_color=primary_colors[2]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y4,
    name='Dartmouth',
    marker_color=primary_colors[3]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y5,
    name='Duke',
    marker_color=primary_colors[4]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y6,
    name='Harvard',
    marker_color=primary_colors[0]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y7,
    name='MIT',
    marker_color=primary_colors[1]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y8,
    name='Princeton',
    marker_color=primary_colors[2]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y9,
    name='Stanford',
    marker_color=primary_colors[3]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y10,
    name='UChicago',
    marker_color=primary_colors[4]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y11,
    name='UPenn',
    marker_color=primary_colors[0]
))

fig.add_trace(go.Scatter(
    x=x,
    y=y12,
    name='Yale',
    marker_color=primary_colors[1]
))
fig.update_layout(title_text="Relative Attendance Rates Across All Scores")

fig.update_layout(yaxis_type="linear")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=12441a0d-cba4-41e8-b639-7c2c88b6450e' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
